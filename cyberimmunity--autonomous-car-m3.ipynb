# %% [markdown]
# # Кибериммунная автономность$\\$Создание конструктивно защищённого автономного наземного транспортного средства$\\$Модуль 3
#
# ## О документе
#
# Версия 1.03
#
# Модуль 3 для регионального этапа соревнований по кибериммунной автономности

# %% [markdown]
# ### Модуль 3. Внедрение блоков функциональной и информационной безопасности
# #### Общая идея
#
# Ключевая идея кибериммунной автономности заключается в том, чтобы уже на этапе проектирования внедрить защиту от кибератак как снаружи, так и изнутри - т.е. через уязвимые бортовые информационные системы.
# Мы исходим из того, что абсолютно защищённых систем не бывает, чем больше и сложнее код, тем проще одним ("плохим") в нём спрятать уязвимости, а другим ("хорошим", но уставшим) эти уязвимости не найти.
#
# Поэтому необходимо сделать так, чтобы наиболее критичный код был отделён от некритичного и протестирован особенно тщательно - таким образом можно снизить вероятность успешной атаки и затруднить задачу атакующим.

# %% [markdown]
# #### Цели и предположения безопасности
#
# ##### Цели безопасности
# Устойчивость кибериммунных систем к атакам выражается в том, что поставленные заказчиком **цели безопасности** (ЦБ) не нарушаются даже в условиях кибератак (снаружи и изнутри).
#
# Для наших автономных машинок заказчиком поставлены следующие ЦБ:
#
# 1. При любых обстоятельствах АНТС осуществляет перемещения в пределах заданных ограничений
#
# 2. При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут
#
# 3. При любых обстоятельствах АНТС оставляет груз только в авторизованном пункте назначения
#
# Ниже используется цифро-буквенное обозначение целей безопасности - например, ЦБ1 - первая цель безопасности из списка выше.
#
# ##### Предположения безопасности
# При этом заказчик согласовал с разработчиками следующие **предположения безопасности** (ПБ) - утверждения о смежных системах, которые снимают с разработчиков часть задач для обеспечения целей безопасности:
#
# 1. При любых обстоятельствах только авторизованный персонал имеет физический доступ к критическим узлам АНТС
#
# 2. При любых обстоятельствах только аутентичные и авторизованные операторы имеют доступ к системе планирования заданий
#
# 3. Аутентичные и авторизованные операторы обладают необходимой квалификацией и являются благонадёжными (т.е. не пытаются намеренно причинить ущерб системе или третьим лицам, используя доступ к АНТС)
#
# Ниже используется цифро-буквенное обозначение предположений безопасности - например, ПБ1 - первое предположение безопасности из списка выше.

# %% [markdown]
# ### Киберпрепятствия
#
# Прежде чем мы начнём внедрять механизмы безопасности, посмотрим, что произойдёт с нашей машинкой, если бортовые системы начнут вести себя не так, как мы ожидаем.
#
# Для этого активируем специальный режим работы системы управления и снова запустим машинку по тому же маршруту, который был в конце модуля 2.
#
# После инициализации системы управления добавьте следующую строку
# ```python
# control_system.enable_surprises()
# ```

# %% [markdown]
# Но вначале нужно из модуля 2 скопировать сюда ваши текущие наработки, а именно ваши реализации классов коммуникационного шлюза (CommunicationGateway), систему навигации (NavigationSystem), управления (ControlSystem), также будем использовать маршрут, который вы создали.

# %%
# вставьте сюда ваш код
from src.config import (
    CONTROL_SYSTEM_QUEUE_NAME,
    DEFAULT_LOG_LEVEL,
    SERVOS_QUEUE_NAME,
    CARGO_BAY_QUEUE_NAME
)
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.event_types import Event
from src.queues_dir import QueuesDirectory
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem
class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """

        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event,
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission",
                      parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_position_to_consumers(self):
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update",
                      parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=speed
                            )

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                                destination=servos_q_name,
                                operation="set_direction",
                                parameters=direction
                                )

        servos_q.put(event_speed)
        servos_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=BaseControlSystem.event_source_name,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="lock_cargo",
                      parameters=None
                      )
        cargo_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        event = Event(source=BaseControlSystem.event_source_name,
                      destination=CARGO_BAY_QUEUE_NAME,
                      operation="release_cargo",
                      parameters=None
                      )
        cargo_q.put(event)

# %% [markdown]
# Если у вас настроена и работает СУПА, установите в True значение переменной afcs_present

# %%
afcs_present = True

# %% [markdown]
# Поменяем идентификатор машинки для этого модуля

# %%
car_id = "m3"

# %%
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(27, 20)
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

# по аналогии собираем все блоки в одном кузове
system_components = SystemComponentsContainer(
    components=[
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ] if afcs_present else [
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system
    ])

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
#################################

system_components.start()

# ограничение поездки по времени
# параметр sleep - время в секундах,
# настройте этот параметр так, чтобы ваша машинка завершила маршрут
# в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного, 
# допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
# при условии, что повторный запуск закончился успешно
sleep(260)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
del system_components
# Out:
# [Point(59.94035299095195, 30.29205322265625, 0.0), Point(59.93819253725659, 30.294424295425415, 0.0), Point(59.93924053610549, 30.298715829849243, 0.0), Point(59.94035433447388, 30.30232608318329, 0.0), Point(59.94100056221525, 30.30405342578888, 0.0), Point(59.94234940448885, 30.30652105808258, 0.0), Point(59.94356922654508, 30.306188464164734, 0.0), Point(59.94434301110533, 30.305153131484985, 0.0), Point(59.9451382708627, 30.303238034248352, 0.0), Point(59.9474943845763, 30.303586721420288, 0.0), Point(59.94826136152058, 30.304858088493347, 0.0), Point(59.94936679794431, 30.304681062698364, 0.0), Point(59.94938828844508, 30.30329167842865, 0.0), Point(59.95095974355276, 30.302948355674744, 0.0), Point(59.95099197774953, 30.300625562667847, 0.0), Point(59.951335807231196, 30.296991169452667, 0.0), Point(59.95176961824593, 30.297232568264008, 0.0), Point(59.952198051415166, 30.296776592731476, 0.0), Point(59.95271243251214, 30.29640644788742, 0.0), Point(59.953506148515174, 30.29652714729309, 0.0), Point(59.9540581123976, 30.29655396938324, 0.0), Point(59.95448651598444, 30.296441316604614, 0.0), Point(59.95598387059525, 30.29905378818512, 0.0), Point(59.95703264999123, 30.300620198249817, 0.0), Point(59.956397477701245, 30.302462875843048, 0.0), Point(59.955359421515325, 30.30640572309494, 0.0), Point(59.95495385903602, 30.307840704917908, 0.0), Point(59.954894, 30.308049, 0.0), Point(59.95515798381817, 30.309364199638367, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека
# [ИНФО][CONTROL] старт системы управления
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 20:17:18.644812
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][CONTROL] новая скорость 60 (была 0)
# [ИНФО][CONTROL] новое направление 151 (было 0)
# [ИНФО][CONTROL] новое направление 150 (было 151)
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 244 (было 150)
# [ИНФО][CONTROL] новое направление 242 (было 244)
# [ИНФО][CONTROL] новое направление 240 (было 242)
# Process MissionSender-1:
# Process CargoBay-9:
# Process MissionPlanner-3:
# Process Servos-8:
# Process TelemetrySender-2:
# Process SITL-4:
# Process NavigationSystem-7:
# Process CommunicationGateway-5:
# Process ControlSystem-6:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/mission_planner.py", line 180, in run
#     sleep(self._recalc_interval_sec)
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/servos.py", line 141, in run
#     sleep(self._recalc_interval_sec)
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/communication_gateway.py", line 108, in run
#     sleep(self._recalc_interval_sec)
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/mission_planner_mqtt.py", line 160, in run
#     sleep(self._recalc_interval_sec)
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/navigation_system.py", line 107, in run
#     sleep(self._recalc_interval_sec)
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/control_system.py", line 268, in run
#     sleep(self._recalc_interval_sec)
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/sitl_mqtt.py", line 162, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/codespace/.python/current/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/cargo_bay.py", line 110, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 97
#      89 system_components.start()
#      91 # ограничение поездки по времени
#      92 # параметр sleep - время в секундах,
#      93 # настройте этот параметр так, чтобы ваша машинка завершила маршрут
#      94 # в случае превышения времени выполнения ячейки на более чем 10 секунд от заданного,
#      95 # допустимо перезапустить вычислительное ядро и повторно выполнить весь блокнот, штрафные очки за это не начисляются
#      96 # при условии, что повторный запуск закончился успешно
# ---> 97 sleep(260)
#      99 # останавливаем все компоненты
#     100 system_components.stop()
#
# KeyboardInterrupt:
#   File "/workspaces/cyberimmune-autonomy--chvt-preview/src/sitl.py", line 186, in run
#     sleep(self._recalc_interval_sec)
# KeyboardInterrupt
# KeyboardInterrupt

# %% [markdown]
# Итак, в отличие от, надеемся, успешного завершения маршрута в модуле 2, сейчас ваша машинка ведёт себя совсем иначе. Например, она внезапно едет в совершенно другую сторону (это особенно хорошо видно при использовании СУПА).
# И это ещё не всё, что может пойти не так..
#
# В этой реализации не очень много кода, теоретически, вы можете его весь изучить и устранить "незадокументированные возможности", однако в реальных системах кода гораздо больше. Например, кодовая база проекта с открытым исходным кодом ArduPilot, реализующего в том числе логику автопилота, составляет примерно миллион строк.
#
# Сколько времени вам понадобится, чтобы изучить и протестировать миллион строк кода? А ведь придётся проводить анализ и каждого обновления.. При этом неприятности могут быть хорошо спрятанными и на первый взгляд безобидными, вряд ли злоумышленники облегчат задачу и назовут свои изменения, например, "hacking_the_system" или "allowing_secret_remote_access". Вредоносный код может выглядеть совершенно безобидно или маскироваться под программный дефект.
#
# Поэтому тщательный анализ потребует большого количества ресурсов (человеческих, вычислительных, временныз), что стоит дорого.
#
# Логичным выходом является выделение критичных для целей безопасности проверок в отдельный блок, который протестировать должно быть гораздо проще.

# %% [markdown]
# #### Задания
#
# В этом модуле задание будет состоять из двух частей разной сложности:
#
# **3.1. добавить новый блок - "Ограничитель"** - этот модуль должен будет обеспечить соблюдение ограничений, указанных в маршрутном задании - это необходимо для обеспечения ЦБ1
#
# **З.2. *(задание повышенной сложности)* добавить монитор безопасности (МБ)** - он должен контролировать все взаимодействия *бортовых систем* (т.е. не включая планировщик и симулятор) и не давать блокам взаимодействовать друг с другом непредусмотренным образом - например, блок №5 может принимать команды только от №3, попытка передать команду в №5 от №2 должна блокироваться нашим монитором безопасности - потенциально это необходимо для обеспечения всех ЦБ

# %% [markdown]
# Для выполнения первой части задачи 3.1. необходимо для начала изменить архитектуру АНТС как показано на рис. 5
#
# ![Архитектура системы с ограничителем](images/ciac-arch-m31.png)
#
# Рис. 5. Архитектура АНТС с ограничителем (для ЦБ1)

# %% [markdown]
# Код базового класса Ограничителя находится в файле src/safety_block.py
#
# По аналогии с заданием в модуле 1, необходимо создать на основе этого класса свой собственный под названием SafetyBlock, в котором реализовать передачу команд в приводы движения, только перед эти необходимо ещё и проконтролировать их безопасность.
#
# Также необходимо реализовать передачу маршрутного задания из CommunicationGateway в SafetyBlock и координат из модуля Navigation в соответствии со стрелками на рис.5 выше.
#
# Если всё сделано правильно, то Ограничителю будет известно следующее
#
# - _mission - текущее маршрутное задание
# - _position - текущие координаты
#
# После проверки нужно установить значение внутренних переменных
# - _speed - текущая (допустимая) скорость
# - _direction - текущее (допустимое) направление
#
# Желательно завершить следование по маршруту. В критической ситуации, если продолжение маршрута невозможно, следует установить значение скорости и направления в 0, после чего передать эти команды в блок приводов (Servos)

# %% [markdown]
# Базовый сценарий для новой архитектуры можно представить следующим образом (см. рис. 6)
#
# ![Базовый сценарий с блоком безопасности](images/basic-scenario-with-safety-block1.png)
#
# Рис. 6. Базовый сценарий с блоком безопасности

# %% [markdown]
# Заготовка кода SafetyBlock
#
# ```python
# class SafetyBlock(BaseSafetyBlock):
#     """ класс ограничений безопасности """
#
#     def _set_new_direction(self, direction: float):
#         """ установка нового направления перемещения """
#         self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
#         self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
#         self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
#         # TODO реализовать контроль безопасности изменения направления
#         self._direction = direction
#         self._send_direction_to_consumers()
#
#     def _set_new_speed(self, speed: float):
#         """ установка новой скорости """
#         # TODO реализовать контроль безопасности изменения скорости
#         self._speed = speed
#         self._send_speed_to_consumers()
#
#
#     def _send_speed_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем скорость получателям")
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_speed",
#                             parameters=self._speed
#                             )
#         servos_q.put(event_speed)
#
#     def _send_direction_to_consumers(self):
#         self._log_message(LOG_DEBUG, "отправляем направление получателям")
#
#         servos_q_name = SERVOS_QUEUE_NAME
#         servos_q: Queue = self._queues_dir.get_queue(servos_q_name)
#
#         # отправка сообщения с желаемой скоростью
#         event_speed = Event(source=self.event_source_name,
#                             destination=servos_q_name,
#                             operation="set_direction",
#                             parameters=self._direction
#                             )
#         servos_q.put(event_speed)
# ```

# %%
# 1. скопируйте сюда код заготовки из предыдущей ячейки и напишите свою реализацию класса SafetyBlock
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event
class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not (self._position and self._route):
            self._log_message(LOG_ERROR, f"неизвестный маршрут или позиция")
            return 
        
        cur_node = self._position
        next_node = self._route.next_point()

        if not next:
            self._log_message(LOG_ERROR, f"достигнут конец маршрута")
            return 
        
        bearing = self._calculate_bearing(cur_node, next_node)
        new_direction = max(bearing - 5, min(bearing + 5, direction))
        
        if new_direction != direction:
            self._log_message(LOG_ERROR, f"попытка изменить направление движения не в ту сторону: {direction}. Скорректировано на {new_direction}")

        self._direction = new_direction
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        # TODO реализовать контроль безопасности изменения скорости

        if not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новую скорость - неизвестный маршрут")
            return

        new_speed = max(0, min(speed, self._route.calculate_speed()))
        if new_speed != speed:
            self._log_message(LOG_ERROR, f"попытка изменить скорость движения на запрещенную: {speed}. Скорректировано на {new_speed}")

        self._speed = new_speed
        self._send_speed_to_consumers()


    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing

# %%
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# 3. создайте экземпляры изменённых классов и отправьте машинку по ранее предложенному маршруту

from src.config import (
    CONTROL_SYSTEM_QUEUE_NAME,
    DEFAULT_LOG_LEVEL,
    SERVOS_QUEUE_NAME,
    CARGO_BAY_QUEUE_NAME
)
from multiprocessing import Queue
from src.communication_gateway import BaseCommunicationGateway
from src.event_types import Event
from src.queues_dir import QueuesDirectory
from src.navigation_system import BaseNavigationSystem
from src.control_system import BaseControlSystem


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """

        # имена очередей блоков находятся в файле src/config.py
        # события нужно отправлять в соответствие с диаграммой информационных потоков
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME

        # события передаются в виде экземпляров класса Event,
        # описание класса находится в файле src/event_types.py
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission",
                      parameters=self._mission
                      )

        # поиск в каталоге нужной очереди (в данном случае - системы управления)
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        # отправка события в найденную очередь
        control_q.put(event)

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_position_to_consumers(self):
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseNavigationSystem.event_source_name,
                      destination=control_q_name,
                      operation="position_update",
                      parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)

        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def __init__(self, queues_dir: QueuesDirectory, log_level=DEFAULT_LOG_LEVEL):
        super().__init__(queues_dir=queues_dir, log_level=log_level)

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                            destination=safety_q_name,
                            operation="set_speed",
                            parameters=speed
                            )

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                                destination=safety_q_name,
                                operation="set_direction",
                                parameters=direction
                                )

        safety_q.put(event_speed)
        safety_q.put(event_direction)

    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=BaseControlSystem.event_source_name,
                      destination=SAFETY_BLOCK_QUEUE_NAME,
                      operation="lock_cargo",
                      parameters=None
                      )
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=BaseControlSystem.event_source_name,
                      destination=SAFETY_BLOCK_QUEUE_NAME,
                      operation="release_cargo",
                      parameters=None
                      )
        safety_q.put(event)

# %%
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(27, 20)
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)
# Out:
# [Point(59.94035299095195, 30.29205322265625, 0.0), Point(59.93819253725659, 30.294424295425415, 0.0), Point(59.93924053610549, 30.298715829849243, 0.0), Point(59.94035433447388, 30.30232608318329, 0.0), Point(59.94100056221525, 30.30405342578888, 0.0), Point(59.94234940448885, 30.30652105808258, 0.0), Point(59.94356922654508, 30.306188464164734, 0.0), Point(59.94434301110533, 30.305153131484985, 0.0), Point(59.9451382708627, 30.303238034248352, 0.0), Point(59.9474943845763, 30.303586721420288, 0.0), Point(59.94826136152058, 30.304858088493347, 0.0), Point(59.94936679794431, 30.304681062698364, 0.0), Point(59.94938828844508, 30.30329167842865, 0.0), Point(59.95095974355276, 30.302948355674744, 0.0), Point(59.95099197774953, 30.300625562667847, 0.0), Point(59.951335807231196, 30.296991169452667, 0.0), Point(59.95176961824593, 30.297232568264008, 0.0), Point(59.952198051415166, 30.296776592731476, 0.0), Point(59.95271243251214, 30.29640644788742, 0.0), Point(59.953506148515174, 30.29652714729309, 0.0), Point(59.9540581123976, 30.29655396938324, 0.0), Point(59.95448651598444, 30.296441316604614, 0.0), Point(59.95598387059525, 30.29905378818512, 0.0), Point(59.95703264999123, 30.300620198249817, 0.0), Point(59.956397477701245, 30.302462875843048, 0.0), Point(59.955359421515325, 30.30640572309494, 0.0), Point(59.95495385903602, 30.307840704917908, 0.0), Point(59.954894, 30.308049, 0.0), Point(59.95515798381817, 30.309364199638367, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель

# %%
# соберём все компоненты для запуска

# в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(260)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       1 # соберём все компоненты для запуска
#       2
#       3 # в зависимости от наличия СУПА используем разный набор компонентов - с передачей телеметрии или без
#       5 system_components = SystemComponentsContainer(
#       6 components=[
#       7         # вариант компонентов с передачей телеметрии в СУПА
# ----> 8         mission_sender,
#       9         telemetry_sender,
#      10         sitl,
#      11         mission_planner,
#      12         navigation_system,
#      13         servos,
#      14         cargo_bay,
#      15         communication_gateway,
#      16         control_system,
#      17         safety_block
#      18     ] if afcs_present else [
#      19         # вариант компонентов для конфигурации без СУПА
#      20         sitl,
#      21         mission_planner,
#      22         navigation_system,
#      23         servos,
#      24         cargo_bay,
#      25         communication_gateway,
#      26         control_system,
#      27         safety_block
#      28     ])
#      30 system_components.start()
#      32 # настройте этот параметр так, чтобы проверить работу ограничителя
#
# NameError: name 'mission_sender' is not defined

# %% [markdown]
# #### Обеспечение ЦБ3: контроль доставки груза
#
# С помощью логики ограничителя выше мы реализовали обеспечение ЦБ1 (соблюдение заданных ограничений), однако есть ещё ЦБ3 (отгрузка только в заданной точке), не говоря о ЦБ2 (следование только по аутентичному маршруту).
#
# Для обеспечения ЦБ3 необходимо сделать следующее
# 1. изменить последовательность передачи команд, чтобы в блок управления грузовым отсеком (CargoBay) команды приходили только после проверки в Ограничителе
# 2. доработайте реализацию Ограничителя, чтобы команда на выгрузку передавалась в CargoBay только в конечной точке маршрута
# 3. продумайте логику работы блока безопасности, если система управления полностью перестанет работать (т.е. перестанет отправлять новые команды).
#
# Изменённая архитектура приведена на рис. 7.
#
# ![Ограничитель для обеспечения ЦБ1 и ЦБ3](images/ciac-arch-m312.png)
#
# Рис. 7. Ограничитель для обеспечения ЦБ1 и ЦБ3

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - неизвестный маршрут или позиция машинки")
            return
        
        current = self._position
        next = self._route.next_point()
        
        if not next:
            self._log_message(LOG_ERROR, f"не получилось установить новое направление - достигнут конец маршрута")
            return
        
        bearing = self._calculate_bearing(current, next)
        
        new_direction = max(bearing - 5, min(bearing + 5, direction))
        
        if new_direction != direction:
            self._log_message(LOG_ERROR, f"попытка изменить направление движения не в ту сторону: {direction}. Скорректировано на {new_direction}")
                
        self._direction = new_direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            self._log_message(LOG_ERROR, f"не получилось установить новую скорость - неизвестный маршрут")
            return

        new_speed = max(0, min(speed, self._route.calculate_speed()))
        if new_speed != speed:
            self._log_message(LOG_ERROR, f"попытка изменить скорость движения на запрещенную: {speed}. Скорректировано на {new_speed}")
                
        self._speed = new_speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        servos_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        servos_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        cargo_q = self._queues_dir.get_queue(CARGO_BAY_QUEUE_NAME)
        cargo_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing
        
# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        safety_q.put(event_speed)
        safety_q.put(event_direction)  
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        safety_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        safety_q = self._queues_dir.get_queue(SAFETY_BLOCK_QUEUE_NAME)
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        safety_q.put(event)      


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        control_q: Queue = self._queues_dir.get_queue(control_q_name)
        control_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        safety_q: Queue = self._queues_dir.get_queue(safety_q_name)
        safety_q.put(event)
        
# создадим все остальные компоненты

# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(27, 20)
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)


system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(260)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.94035299095195, 30.29205322265625, 0.0), Point(59.93819253725659, 30.294424295425415, 0.0), Point(59.93924053610549, 30.298715829849243, 0.0), Point(59.94035433447388, 30.30232608318329, 0.0), Point(59.94100056221525, 30.30405342578888, 0.0), Point(59.94234940448885, 30.30652105808258, 0.0), Point(59.94356922654508, 30.306188464164734, 0.0), Point(59.94434301110533, 30.305153131484985, 0.0), Point(59.9451382708627, 30.303238034248352, 0.0), Point(59.9474943845763, 30.303586721420288, 0.0), Point(59.94826136152058, 30.304858088493347, 0.0), Point(59.94936679794431, 30.304681062698364, 0.0), Point(59.94938828844508, 30.30329167842865, 0.0), Point(59.95095974355276, 30.302948355674744, 0.0), Point(59.95099197774953, 30.300625562667847, 0.0), Point(59.951335807231196, 30.296991169452667, 0.0), Point(59.95176961824593, 30.297232568264008, 0.0), Point(59.952198051415166, 30.296776592731476, 0.0), Point(59.95271243251214, 30.29640644788742, 0.0), Point(59.953506148515174, 30.29652714729309, 0.0), Point(59.9540581123976, 30.29655396938324, 0.0), Point(59.95448651598444, 30.296441316604614, 0.0), Point(59.95598387059525, 30.29905378818512, 0.0), Point(59.95703264999123, 30.300620198249817, 0.0), Point(59.956397477701245, 30.302462875843048, 0.0), Point(59.955359421515325, 30.30640572309494, 0.0), Point(59.95495385903602, 30.307840704917908, 0.0), Point(59.954894, 30.308049, 0.0), Point(59.95515798381817, 30.309364199638367, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 275
#     272 # каталог очередей для передачи сообщений между блоками
#     273 queues_dir = QueuesDirectory()
# --> 275 if afcs_present:
#     276     mission_sender = MissionSender(
#     277         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
#     278     telemetry_sender = TelemetrySender(
#     279         queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
#
# NameError: name 'afcs_present' is not defined

# %% [markdown]
# #### *Опциональное задание повышенной сложности* Обеспечение ЦБ2
#
# **Перед началом работы над этой задачей рекомендуем сохранить все текущие изменения в git репозитории (git commit, git push).**
#
# Напомним цель безопасности №2 (ЦБ2): "При любых обстоятельствах АНТС выполняет только аутентичный (подлинный) маршрут"
#
# Обеспечение ЦБ2 потребует
# - внедрения механизма **контроля аутентичности маршрутного задания** (mission), а значит
# - помимо изменения **блока безопасности** (SafetyBlock), модификации
#   - системы **планирования задания** (MissionPlanner)
#   - **коммуникационного шлюза** (CommunicationGateway)
#   - и, возможно, **системы управления** (ControlSystem).
#
# Для решения этой задачи допустимо менять код соответствующих модулей в папке src.
#
# Возможным решением является внедрение механизма цифровой подписи, верификацией которой будет заниматься блок безопасности. В этой ситуации если коммуникационный шлюз (блок "1. Связь" на рис. 5 в модуле 1) оказался скомпрометированным и изменил маршрутное задание, оно не должно пройти проверку подлинности в блоке безопасности.
#
# **Рекомендуем эту задачу делать в последнюю очередь**, *после успешного выполнения модуля 4*, поскольку успешное выполнение модуля 4 принесёт больше баллов, чем внедрение цифровой подписи и обеспечение ЦБ2.
# К сведению, реализованные в этой версии киберпрепятствия не предполагают компрометацию маршрутного задания.
#
# Конечно, если будут решены все основные задачи и к тому же обеспечен контроль аутентичности маршрутного задания, такая работа с высокой вероятностью окажется лучшей.

# %%
# если вы собираетесь выполнить это задание, напишите в этой ячейке код выполнения изменённых блоков. 
# cам код допускается редактировать в папке src
# в случае успешной реализации машинка должна успешно пройти по маршруту, а в случае искажения маршрутного задания в блоке коммуникационного шлюза должна остаться на месте, 
# при этом именно блок безопасности должен заблокировать движение

# %% [markdown]
# ### Задание 3.2. Монитор безопасности

# %% [markdown]
# В текущей реализации каждый блок сам решает куда и какие данные ему отправлять. Это приемлемо, когда каждый блок рассматривается как благонадёжный. Однако нельзя исключать ситуацию успешной компрометации какого-либо из блоков (одного или нескольких), в результате которой злоумышленник может получить полный контроль над частью системы.
#
# В такой ситуации необходимо выстроить внутреннюю "поверхность защиты", частью этой системы уже является блок "Ограничитель", однако необходимо сделать так, чтобы соответствующие запросы проходили только через него, а не в обход.
#
# Для решения этой задачи необходимо добавить новый блок "Монитор безопасности". Его задача - обеспечить контроль направления информационных потоков, допустить передачу данных только между теми блоками и в тех направлениях, которые задуманы архитектором системы. Тогда, например, попытка передать команду из системы управления напрямую в сервоприводы в обход ограничителя будет заблокирована.
#
# Возможно, возникнет вопрос, а что помешает злоумышленнику отправить команду в обход этого монитора безопасности. В рамках этой учебной инфраструктуры особо ничего, однако при разработке реальной системы можно использовать специализированные микроядерные операционные системы, такие как, например, KasperskyOS, которые обеспечат обязательное вовлечение монитора безопасности в контроль взаимодействия между блоками.
#
# Архитектура системы для решения задачи 3.2 должна выглядеть как на рис.8:
#
# ![Архитектура системы с монитором безопасности](images/ciac-arch-m32.png)
#
# Рис. 8. Архитектура бортовых систем с монитором безопасности

# %% [markdown]
# Базовый класс модуля безопасности находится в файле src/security_monitor.py, его менять не нужно.
#
# В следующей ячейке находится реализация класса SecurityMonitor

# %%
from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import COMMUNICATION_GATEWAY_QUEUE_NAME, LOG_DEBUG, LOG_ERROR, LOG_INFO
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission')
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %% [markdown]
# Обратите внимание на этот код:
# ```python
#     def _init_set_security_policies(self):
#         """ инициализация политик безопасности """
#         default_policies = [
#             SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
#         ]
#         self.set_security_policies(policies=default_policies)
# ```
#
# В нём инициализируется политика безопасности, разрешающая запрос set_mission от коммуникационного шлюза в систему управления.
#
# Код политики безопасности в строка 6-9:
# ```python
# SecurityPolicy(
#                 source=COMMUNICATION_GATEWAY_QUEUE_NAME,
#                 destination=CONTROL_SYSTEM_QUEUE_NAME,
#                 operation='set_mission')
# ```
#
# Шаблон политики безопасности описан в файле src/security_policy_type.py:
# ```python
# @dataclass
# class SecurityPolicy:
#     """ политика безопасности """
#     source: str         # отправитель запроса
#     destination: str    # получатель
#     operation: str      # запрашиваемая операция
#
# ```
#
# По аналогии в методе _init_set_security_policies допишите другие политики безопасности, чтобы разрешить взаимодействия согласно диаграмме на рис.7. выше.

# %% [markdown]
# Теперь необходимо изменить взаимодействие между блоками так, чтобы оно всегда проходило через монитор безопасности. Для этого потребуется изменить соответствующие реализации внутренних блоков.

# %% [markdown]
# Ниже пример для блока навигации. Обратите внимание на выделенные строки и комментарии.
#
# ```python
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         # событие для системы управления,
#         # поэтому в destination указываем CONTROL_SYSTEM_QUEUE_NAME
#         event = Event(source=self.event_source_name,
# >>>                      destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         # но событие отправляем сначала на проверку в монитор безопасности,
#         # поэтому используем очередь с именем SECURITY_MONITOR_QUEUE_NAME
# >>>        security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#         # а в систему управления наше событие монитор безопасности отправит сам, если найдёт разрешающую эту операцию политику безопасности
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)
# ```

# %% [markdown]
# from src.navigation_system import BaseNavigationSystem
# from src.config import CONTROL_SYSTEM_QUEUE_NAME, SECURITY_MONITOR_QUEUE_NAME
#
#
# class NavigationSystem(BaseNavigationSystem):
#     """ класс навигационного блока """
#     def _send_position_to_consumers(self):
#         event = Event(source=self.event_source_name,
#                       destination=CONTROL_SYSTEM_QUEUE_NAME,
#                       operation="position_update", parameters=self._position
#                       )
#         security_monitor_q: Queue = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
#         security_monitor_q.put(event)
#
# navigation_system = NavigationSystem(queues_dir=queues_dir)

# %% [markdown]
# В файле tests/module/test_security_monitor.py можно увидеть тест логики работы монитора безопасности. Запустить его можно следующей командой:

# %%
# !pytest -svk security_monitor
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.1, pytest-8.3.5, pluggy-1.5.0 -- /usr/local/py-utils/venvs/pytest/bin/python
# cachedir: .pytest_cache
# rootdir: /workspaces/cyberimmune-autonomy--chvt-preview
# configfile: pytest.ini
# testpaths: tests
# plugins: anyio-4.9.0
# collected 1 item
#
# tests/module/test_security_monitor.py::test_security_policies [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='control', operation='set_mission', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='control', destination='safety', operation='set_speed')]
# [ОТЛАДКА][SECURITY] проверка события Event(source='control', destination='safety', operation='set_speed', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# [ОТЛАДКА][SECURITY] событие разрешено политиками, выполняем
# [ОТЛАДКА][SECURITY] проверка события Event(source='communication', destination='cargo', operation='release_cargo', parameters=None, extra_parameters=None, signature=None), по умолчанию выполнение запрещено
# PASSED
#
# ============================== 1 passed in 0.01s ===============================

# %% [markdown]
# В одном кодовом блоке ниже (или нескольких - как будет удобнее)  сделайте следующее
#
# 1. Измените реализацию монитора безопасности в части правил проверки передаваемых сообщений в мониторе безопасности
# 2. Измените параметры отправки сообщений между элементами бортовых систем (блоками 1-7), чтобы они всегда отправлялись в очередь монитора безопасности (отправитель и получатель при этом не меняются)
# 3. После всех изменений убедитесь в том, что машинка по-прежнему успешно выполняет маршрутное задание и доставляет груз
# 4. Дополнительные баллы принесут автоматические тесты правил безопасности в файле tests/module/test_security_monitor.py - можно проверить, что все новые политики работают как ожидаются, а недопустимые взаимодействия (т.е. таких стрелок нет на рис. 8) блокируются

# %%
# добавьте изменения сюда

from src.security_monitory import BaseSecurityMonitor
from src.security_policy_type import SecurityPolicy

from src.config import *
    
    
class SecurityMonitor(BaseSecurityMonitor):
    """ класс монитора безопасности """

    def __init__(self, queues_dir):
        super().__init__(queues_dir)
        self._init_set_security_policies()

    def _init_set_security_policies(self):
        """ инициализация политик безопасности """
        default_policies = [
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='set_mission'),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_mission"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=NAVIGATION_QUEUE_NAME,
                operation="request_position"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=NAVIGATION_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation="position_update"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="lock_cargo"),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="release_cargo"),            
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_speed"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=SERVOS_QUEUE_NAME,
                operation="set_direction"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="release_cargo"),
            SecurityPolicy(
                source=SAFETY_BLOCK_QUEUE_NAME,
                destination=CARGO_BAY_QUEUE_NAME,
                operation="lock_cargo"),
            SecurityPolicy(
                source=COMMUNICATION_GATEWAY_QUEUE_NAME,
                destination=CONTROL_SYSTEM_QUEUE_NAME,
                operation='position_update'),
            SecurityPolicy(
                source=CONTROL_SYSTEM_QUEUE_NAME,
                destination=SAFETY_BLOCK_QUEUE_NAME,
                operation="position_update"),
        ]
        self.set_security_policies(policies=default_policies)        

    def set_security_policies(self, policies):
        """ установка новых политик безопасности """
        self._security_policies = policies
        self._log_message(
            LOG_INFO, f"изменение политик безопасности: {policies}")

    def _check_event(self, event: Event):
        """ проверка входящих событий """
        self._log_message(
            LOG_DEBUG, f"проверка события {event}, по умолчанию выполнение запрещено")

        authorized = False
        request = SecurityPolicy(
            source=event.source,
            destination=event.destination,
            operation=event.operation)

        if request in self._security_policies:
            self._log_message(
                LOG_DEBUG, "событие разрешено политиками, выполняем")
            authorized = True

        if authorized is False:
            self._log_message(LOG_ERROR, f"событие не разрешено политиками безопасности! {event}")
        return authorized

# %%
from src.safety_block import BaseSafetyBlock
from src.config import *
import math
from time import sleep
from geopy import Point as GeoPoint
from src.config import LOG_ERROR, LOG_INFO, LOG_DEBUG
from multiprocessing import Queue
from src.config import SERVOS_QUEUE_NAME
from src.event_types import Event


# 2. напишите в этом блоке реализацию изменённых блоков связи, управления и навигации, 
# чтобы передавать данные согласно изменённой архитектуре на рис. 5 для обеспечения работы по сценарию на рис.6

# вставьте сюда ваш код
from src.control_system import BaseControlSystem
from src.navigation_system import BaseNavigationSystem
from src.communication_gateway import BaseCommunicationGateway
from multiprocessing import Queue
from src.config import SAFETY_BLOCK_QUEUE_NAME
from src.config import SERVOS_QUEUE_NAME
from src.config import CONTROL_SYSTEM_QUEUE_NAME
from src.event_types import Event


class ControlSystem(BaseControlSystem):
    """ControlSystem блок расчёта управления """

    def _send_speed_and_direction_to_consumers(self, speed, direction):
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_speed", parameters=speed
                    ) # замените на код создания сообщения со скоростью для приводов
                           # подсказка, требуемая операция - set_speed

        # отправка сообщения с желаемым направлением
        event_direction = Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="set_direction", parameters=direction
                    ) # замените на код создания сообщения с направлением для приводов
                               # подсказка, требуемая операция - set_direction

        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_direction)
        security_monitor_q.put(event_speed)
        
    def _lock_cargo(self):
        """ заблокировать грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME,
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="lock_cargo", parameters= None
                    )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _release_cargo(self):
        """ открыть грузовой отсек """
        event = Event(source=CONTROL_SYSTEM_QUEUE_NAME, 
                    destination=SAFETY_BLOCK_QUEUE_NAME,
                    operation="release_cargo", parameters= None
                    )  
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class CommunicationGateway(BaseCommunicationGateway):
    """CommunicationGateway класс для реализации логики взаимодействия
    с системой планирования заданий

    Работает в отдельном процессе, поэтому создаётся как наследник класса Process
    """
    def _send_mission_to_consumers(self):
        """ метод для отправки сообщения с маршрутным заданием в систему управления """
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
                
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=safety_q_name,
                      operation="set_mission", parameters=self._mission
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)


class NavigationSystem(BaseNavigationSystem):
    """ класс навигационного блока """
    def _send_position_to_consumers(self):        
        control_q_name = CONTROL_SYSTEM_QUEUE_NAME
        event = Event(source=BaseCommunicationGateway.event_source_name,
                      destination=control_q_name,
                      operation="position_update", parameters=self._position
                      )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
      
        safety_q_name = SAFETY_BLOCK_QUEUE_NAME # замените на правильное название очереди
        event =  Event(source=BaseControlSystem.event_source_name,
                      destination=safety_q_name,
                      operation="position_update", parameters=self._position
                    ) # замените на код создания сообщения с координатами для системы управления 
                     # подсказка, требуемая операция - position_update
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

class SafetyBlock(BaseSafetyBlock):
    """ класс ограничений безопасности """

    def _set_new_direction(self, direction: float):
        """ установка нового направления перемещения """
        self._log_message(LOG_INFO, f"текущие координаты: {self._position}")
        self._log_message(LOG_DEBUG, f"маршрутное задание: {self._mission}")
        self._log_message(LOG_DEBUG, f"состояние маршруте: {self._route}")
        # TODO реализовать контроль безопасности изменения направления

        if not self._position or not self._route:
            return
        
        current = self._position
        next = self._route.next_point()
        bearing = self._calculate_bearing(current, next)
        
        direction = max(bearing - 5, min(bearing + 5, direction))
                
        self._direction = direction
        # отправка сообщения с желаемым направлением
        self._send_direction_to_consumers()

    def _set_new_speed(self, speed: float):
        """ установка новой скорости """
        if not self._route:
            return

        speed = max(0, min(speed, self._route.calculate_speed()))

        self._speed = speed
        self._send_speed_to_consumers()

    def _send_speed_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем скорость получателям")
        servos_q_name = SERVOS_QUEUE_NAME

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_speed",
                            parameters=self._speed
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _send_direction_to_consumers(self):
        self._log_message(LOG_DEBUG, "отправляем направление получателям")

        servos_q_name = SERVOS_QUEUE_NAME
        servos_q: Queue = self._queues_dir.get_queue(servos_q_name)

        # отправка сообщения с желаемой скоростью
        event_speed = Event(source=self.event_source_name,
                            destination=servos_q_name,
                            operation="set_direction",
                            parameters=self._direction
                            )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event_speed)

    def _lock_cargo(self, _):
        self._log_message(LOG_INFO, "Блокировка грузового отсека")
        self._send_lock_cargo_to_consumers()

    def _send_lock_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду блокировки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="lock_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)
        
    def _release_cargo(self, _):
        if not self._route or not self._route.route_finished:
            self._log_message(LOG_DEBUG, "Не разрешили открыть груз тк не на маршруте или не закончили его")
            return
        self._send_release_cargo_to_consumers()

    def _send_release_cargo_to_consumers(self):
        self._log_message(LOG_DEBUG, "Отправляем команду выгрузки в CargoBay")
        event = Event(
            source=self.event_source_name,
            destination=CARGO_BAY_QUEUE_NAME,
            operation="release_cargo",
            parameters=None
        )
        security_monitor_q = self._queues_dir.get_queue(SECURITY_MONITOR_QUEUE_NAME)
        security_monitor_q.put(event)

    def _calculate_bearing(self, start: GeoPoint, end: GeoPoint):
        delta_longitude = end.longitude - start.longitude
        x = math.sin(math.radians(delta_longitude)) * \
            math.cos(math.radians(end.latitude))
        y = math.cos(math.radians(start.latitude)) * math.sin(math.radians(end.latitude)) - \
            math.sin(math.radians(start.latitude)) * math.cos(math.radians(end.latitude)) * \
            math.cos(math.radians(delta_longitude))
        initial_bearing_rad = math.atan2(x, y)

        # Преобразуем радианы в градусы
        initial_bearing_deg = math.degrees(initial_bearing_rad)

        # Нормализуем значение в диапазоне [0, 360]
        compass_bearing = (initial_bearing_deg + 360) % 360

        return compass_bearing
        
# используем то же маршрутное задание, которое было в модуле 2
from time import sleep
from geopy import Point as GeoPoint


from src.queues_dir import QueuesDirectory
from src.servos import Servos
from src.sitl import SITL
from src.cargo_bay import CargoBay
from src.mission_planner import MissionPlanner
from src.config import LOG_ERROR, LOG_INFO
from src.mission_planner_mqtt import MissionSender
from src.mission_planner import Mission
from src.sitl_mqtt import TelemetrySender
from src.system_wrapper import SystemComponentsContainer
from src.wpl_parser import WPLParser


# возьмём маршрут из модуля 2
wpl_file = "module2.wpl"

parser = WPLParser(wpl_file)    
points = parser.parse()
print(points)

from src.mission_type import GeoSpecificSpeedLimit
speed_limits = [
    GeoSpecificSpeedLimit(0, 60),
    GeoSpecificSpeedLimit(27, 20)
]


home = points[0]
mission = Mission(home=home, waypoints=points,speed_limits=speed_limits, armed=True)

# каталог очередей для передачи сообщений между блоками
queues_dir = QueuesDirectory() 

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

communication_gateway = CommunicationGateway(
    queues_dir=queues_dir, log_level=LOG_ERROR)
control_system = ControlSystem(queues_dir=queues_dir, log_level=LOG_INFO)

#################################
# АКТИВАЦИЯ КИБЕРПРЕПЯТСТВИЙ
control_system.enable_surprises()
################################

navigation_system = NavigationSystem(
    queues_dir=queues_dir, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

if afcs_present:
    mission_sender = MissionSender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)
    telemetry_sender = TelemetrySender(
        queues_dir=queues_dir, client_id=car_id, log_level=LOG_ERROR)

mission_planner = MissionPlanner(
    queues_dir, afcs_present=afcs_present, mission=mission)

sitl = SITL(
    queues_dir=queues_dir, position=home,
    car_id=car_id, post_telemetry=afcs_present, log_level=LOG_ERROR)

servos = Servos(queues_dir=queues_dir, log_level=LOG_ERROR)
cargo_bay = CargoBay(queues_dir=queues_dir, log_level=LOG_INFO)

safety_block = SafetyBlock(queues_dir=queues_dir, log_level=LOG_INFO)

security_monitor = SecurityMonitor(queues_dir=queues_dir)

system_components = SystemComponentsContainer(
components=[
        # вариант компонентов с передачей телеметрии в СУПА
        mission_sender,
        telemetry_sender,
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        security_monitor,
        communication_gateway,
        control_system,
        safety_block
    ] if afcs_present else [
        # вариант компонентов для конфигурации без СУПА
        sitl,
        mission_planner,
        navigation_system,
        servos,
        cargo_bay,
        security_monitor,
        communication_gateway,
        control_system,
        safety_block
    ])

system_components.start()

# настройте этот параметр так, чтобы проверить работу ограничителя
sleep(260)

# останавливаем все компоненты
system_components.stop()

# удалим все созданные компоненты
system_components.clean()
# Out:
# [Point(59.94035299095195, 30.29205322265625, 0.0), Point(59.93819253725659, 30.294424295425415, 0.0), Point(59.93924053610549, 30.298715829849243, 0.0), Point(59.94035433447388, 30.30232608318329, 0.0), Point(59.94100056221525, 30.30405342578888, 0.0), Point(59.94234940448885, 30.30652105808258, 0.0), Point(59.94356922654508, 30.306188464164734, 0.0), Point(59.94434301110533, 30.305153131484985, 0.0), Point(59.9451382708627, 30.303238034248352, 0.0), Point(59.9474943845763, 30.303586721420288, 0.0), Point(59.94826136152058, 30.304858088493347, 0.0), Point(59.94936679794431, 30.304681062698364, 0.0), Point(59.94938828844508, 30.30329167842865, 0.0), Point(59.95095974355276, 30.302948355674744, 0.0), Point(59.95099197774953, 30.300625562667847, 0.0), Point(59.951335807231196, 30.296991169452667, 0.0), Point(59.95176961824593, 30.297232568264008, 0.0), Point(59.952198051415166, 30.296776592731476, 0.0), Point(59.95271243251214, 30.29640644788742, 0.0), Point(59.953506148515174, 30.29652714729309, 0.0), Point(59.9540581123976, 30.29655396938324, 0.0), Point(59.95448651598444, 30.296441316604614, 0.0), Point(59.95598387059525, 30.29905378818512, 0.0), Point(59.95703264999123, 30.300620198249817, 0.0), Point(59.956397477701245, 30.302462875843048, 0.0), Point(59.955359421515325, 30.30640572309494, 0.0), Point(59.95495385903602, 30.307840704917908, 0.0), Point(59.954894, 30.308049, 0.0), Point(59.95515798381817, 30.309364199638367, 0.0)]
# [ИНФО][QUEUES] создан каталог очередей
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь communication
# [ИНФО][QUEUES] регистрируем очередь control
# [ИНФО][CONTROL] создана система управления
# [ИНФО][QUEUES] регистрируем очередь navigation
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь planner.mqtt
# [ИНФО][QUEUES] регистрируем очередь sitl.mqtt
# [ИНФО][QUEUES] регистрируем очередь planner
# [ИНФО][MISSION PLANNER] создана система планирования заданий
# [ИНФО][QUEUES] регистрируем очередь sitl
# [ИНФО][QUEUES] регистрируем очередь servos
# [ИНФО][QUEUES] регистрируем очередь cargo
# [ИНФО][CARGO] создан компонент грузового отсека, отсек заблокирован
# [ИНФО][QUEUES] регистрируем очередь safety
# [ИНФО][SAFETY] создан ограничитель
# [ИНФО][QUEUES] регистрируем очередь security
# [ИНФО][SECURITY] создан монитор безопасности
# [ИНФО][SECURITY] изменение политик безопасности: [SecurityPolicy(source='communication', destination='control', operation='set_mission'), SecurityPolicy(source='communication', destination='safety', operation='set_mission'), SecurityPolicy(source='control', destination='navigation', operation='request_position'), SecurityPolicy(source='navigation', destination='safety', operation='position_update'), SecurityPolicy(source='navigation', destination='control', operation='position_update'), SecurityPolicy(source='control', destination='safety', operation='set_speed'), SecurityPolicy(source='control', destination='safety', operation='set_direction'), SecurityPolicy(source='control', destination='safety', operation='lock_cargo'), SecurityPolicy(source='control', destination='safety', operation='release_cargo'), SecurityPolicy(source='safety', destination='servos', operation='set_speed'), SecurityPolicy(source='safety', destination='servos', operation='set_direction'), SecurityPolicy(source='safety', destination='cargo', operation='release_cargo'), SecurityPolicy(source='safety', destination='cargo', operation='lock_cargo'), SecurityPolicy(source='communication', destination='control', operation='position_update'), SecurityPolicy(source='control', destination='safety', operation='position_update')]
# [ИНФО][MISSION PLANNER] старт системы планирования заданий
# [ИНФО][CARGO] старт блока грузового отсека[ИНФО][SECURITY] старт блока грузового отсека
#
# [ИНФО][CONTROL] старт системы управления[ИНФО][SAFETY] старт ограничителя
#
# [ИНФО][MISSION PLANNER] запрошена новая задача, отправляем получателям
# [ИНФО][MISSION PLANNER] новая задача отправлена в коммуникационный шлюз
# [ИНФО][CONTROL] установлена новая задача, начинаем следовать по маршруту, текущее время 20:19:18.455268
# [ИНФО][SAFETY] Блокировка грузового отсека
# [ИНФО][CONTROL] новая скорость 60 (была 0)
# [ИНФО][CONTROL] новое направление 151 (было 0)
# [ИНФО][CARGO] заблокировать грузовой отсек
# [ИНФО][CARGO] грузовой отсек заблокирован
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2708s N, 30 17m 31.3916s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2708s N, 30 17m 31.3916s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2708s N, 30 17m 31.3916s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2708s N, 30 17m 31.3916s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.0348s N, 30 17m 31.6502s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.846s N, 30 17m 31.857s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.6101s N, 30 17m 32.1155s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.3741s N, 30 17m 32.3741s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.1381s N, 30 17m 32.6326s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.9022s N, 30 17m 32.8912s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.6662s N, 30 17m 33.1498s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.4303s N, 30 17m 33.4084s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.1943s N, 30 17m 33.667s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.9584s N, 30 17m 33.9256s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.7224s N, 30 17m 34.1842s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.4865s N, 30 17m 34.4428s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.2506s N, 30 17m 34.7015s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.0146s N, 30 17m 34.9602s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.7787s N, 30 17m 35.2189s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.5428s N, 30 17m 35.4776s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.3069s N, 30 17m 35.7363s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.071s N, 30 17m 35.995s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.8351s N, 30 17m 36.2538s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.5992s N, 30 17m 36.5126s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.3633s N, 30 17m 36.7714s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.1274s N, 30 17m 37.0302s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.8915s N, 30 17m 37.289s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.6557s N, 30 17m 37.5479s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4198s N, 30 17m 37.8069s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.184s N, 30 17m 38.0658s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.9481s N, 30 17m 38.3248s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.7123s N, 30 17m 38.5839s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.4765s N, 30 17m 38.843s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.2407s N, 30 17m 39.1021s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.005s N, 30 17m 39.3614s E
# [ИНФО][CONTROL] новое направление 150 (было 151)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.7692s N, 30 17m 39.6208s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 244 (было 150)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.5335s N, 30 17m 39.8803s E
# [ИНФО][CONTROL] новое направление 242 (было 244)
# [ИНФО][CONTROL] новое направление 240 (было 242)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.2979s N, 30 17m 40.14s E
# [ИНФО][CONTROL] новое направление 238 (было 240)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.0623s N, 30 17m 40.4s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 16.827s N, 30 17m 40.661s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 16.9221s N, 30 17m 41.163s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.0251s N, 30 17m 41.6589s E
# [ИНФО][CONTROL] новое направление 237 (было 238)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.1357s N, 30 17m 42.1481s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.254s N, 30 17m 42.6302s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.3737s N, 30 17m 43.1109s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.4946s N, 30 17m 43.5904s E
# [ИНФО][CONTROL] новое направление 236 (было 237)
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.6166s N, 30 17m 44.0689s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.7394s N, 30 17m 44.5464s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.8631s N, 30 17m 45.023s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 17.9878s N, 30 17m 45.4987s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.1133s N, 30 17m 45.9734s E
# [ИНФО][CONTROL] новое направление 235 (было 236)
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.2398s N, 30 17m 46.4472s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.3674s N, 30 17m 46.9198s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.4971s N, 30 17m 47.3901s E
# [ИНФО][CONTROL] новое направление 234 (было 235)
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.628s N, 30 17m 47.8591s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.7336s N, 30 17m 48.2332s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 18.8667s N, 30 17m 48.6996s E
# [ИНФО][CONTROL] новое направление 233 (было 234)
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.0014s N, 30 17m 49.1643s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.1372s N, 30 17m 49.6277s E
# [ИНФО][CONTROL] новое направление 232 (было 233)
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.2745s N, 30 17m 50.0894s E
# [ИНФО][CONTROL] новое направление 231 (было 232)
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.4134s N, 30 17m 50.5492s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.5539s N, 30 17m 51.0069s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.6945s N, 30 17m 51.4646s E
# [ИНФО][CONTROL] новое направление 230 (было 231)
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.837s N, 30 17m 51.92s E
# [ИНФО][CONTROL] новое направление 229 (было 230)
# [ИНФО][SAFETY] текущие координаты: 59 56m 19.9815s N, 30 17m 52.3728s E
# [ИНФО][CONTROL] новое направление 228 (было 229)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.131s N, 30 17m 52.8192s E
# [ИНФО][CONTROL] новое направление 227 (было 228)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.2836s N, 30 17m 53.2613s E
# [ИНФО][CONTROL] новое направление 225 (было 227)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.4399s N, 30 17m 53.6983s E
# [ИНФО][CONTROL] новое направление 223 (было 225)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.6002s N, 30 17m 54.1295s E
# [ИНФО][CONTROL] новое направление 219 (было 223)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.7653s N, 30 17m 54.5533s E
# [ИНФО][CONTROL] новое направление 211 (было 219)
# [ИНФО][SAFETY] текущие координаты: 59 56m 20.9366s N, 30 17m 54.9675s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 160 (была 60)
# [ИНФО][CONTROL] новое направление 57 (было 211)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.1161s N, 30 17m 55.3675s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.3082s N, 30 17m 55.7436s E
# [ИНФО][CONTROL] новое направление 58 (было 57)
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.5235s N, 30 17m 56.0659s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.6684s N, 30 17m 56.5182s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.8114s N, 30 17m 56.9729s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 21.9514s N, 30 17m 57.4313s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.0912s N, 30 17m 57.89s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.2309s N, 30 17m 58.3488s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.3705s N, 30 17m 58.8077s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.5102s N, 30 17m 59.2665s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.6498s N, 30 17m 59.7254s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.7894s N, 30 18m 0.184323s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 22.929s N, 30 18m 0.643238s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.0685s N, 30 18m 1.10217s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.2081s N, 30 18m 1.56111s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.3477s N, 30 18m 2.02007s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.4872s N, 30 18m 2.47904s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.6267s N, 30 18m 2.93803s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.7663s N, 30 18m 3.39704s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 23.9058s N, 30 18m 3.85607s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.0452s N, 30 18m 4.31512s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.1847s N, 30 18m 4.7742s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.3242s N, 30 18m 5.2333s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.4636s N, 30 18m 5.69243s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.603s N, 30 18m 6.1516s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.7423s N, 30 18m 6.6108s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 24.8816s N, 30 18m 7.07006s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.0209s N, 30 18m 7.52938s E
# [ИНФО][CONTROL] новое направление 59 (было 58)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.1601s N, 30 18m 7.98879s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 60 (была 160)
# [ИНФО][CONTROL] новое направление 53 (было 59)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.2992s N, 30 18m 8.44832s E
# [ИНФО][CONTROL] новое направление 52 (было 53)
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.4381s N, 30 18m 8.90807s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.5764s N, 30 18m 9.3685s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.7377s N, 30 18m 9.79819s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 25.9007s N, 30 18m 10.2255s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.0655s N, 30 18m 10.6498s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.2307s N, 30 18m 11.0737s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.396s N, 30 18m 11.4974s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.5613s N, 30 18m 11.9209s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.6936s N, 30 18m 12.2598s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 26.859s N, 30 18m 12.6833s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.0243s N, 30 18m 13.107s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.1896s N, 30 18m 13.5306s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.3548s N, 30 18m 13.9544s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 42 (было 52)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.52s N, 30 18m 14.3783s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.685s N, 30 18m 14.8024s E
# [ИНФО][CONTROL] новое направление 41 (было 42)
# [ИНФО][SAFETY] текущие координаты: 59 56m 27.8498s N, 30 18m 15.2268s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.0476s N, 30 18m 15.5908s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.2468s N, 30 18m 15.952s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.4473s N, 30 18m 16.3103s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.6479s N, 30 18m 16.6683s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 28.8485s N, 30 18m 17.0264s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.0491s N, 30 18m 17.3843s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.2498s N, 30 18m 17.7421s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.4504s N, 30 18m 18.1s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.6511s N, 30 18m 18.458s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 29.8517s N, 30 18m 18.8159s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.0524s N, 30 18m 19.1739s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.253s N, 30 18m 19.5318s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.4536s N, 30 18m 19.8899s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.6542s N, 30 18m 20.2479s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 30.8547s N, 30 18m 20.606s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.0553s N, 30 18m 20.9641s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.2558s N, 30 18m 21.3223s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.4563s N, 30 18m 21.6805s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.6568s N, 30 18m 22.0388s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 31.8573s N, 30 18m 22.3972s E
# [ИНФО][CONTROL] новое направление 42 (было 41)
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.0577s N, 30 18m 22.7556s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.2581s N, 30 18m 23.1142s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 352 (было 42)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.4583s N, 30 18m 23.4729s E
# [ИНФО][CONTROL] новое направление 349 (было 352)
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.6585s N, 30 18m 23.8318s E
# [ИНФО][CONTROL] новое направление 346 (было 349)
# [ИНФО][SAFETY] текущие координаты: 59 56m 32.8585s N, 30 18m 24.1912s E
# [ИНФО][CONTROL] новое направление 343 (было 346)
# [ИНФО][SAFETY] текущие координаты: 59 56m 33.058s N, 30 18m 24.5516s E
# [ИНФО][CONTROL] новое направление 342 (было 343)
# [ИНФО][SAFETY] текущие координаты: 59 56m 33.3249s N, 30 18m 24.4792s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 33.5896s N, 30 18m 24.3812s E
# [ИНФО][CONTROL] новое направление 341 (было 342)
# [ИНФО][SAFETY] текущие координаты: 59 56m 33.8514s N, 30 18m 24.2559s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 34.1093s N, 30 18m 24.1016s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 34.3663s N, 30 18m 23.9414s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 34.6226s N, 30 18m 23.7764s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 34.8782s N, 30 18m 23.608s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 35.1337s N, 30 18m 23.4383s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 35.389s N, 30 18m 23.2676s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 35.6442s N, 30 18m 23.0962s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 35.8993s N, 30 18m 22.9245s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 36.1543s N, 30 18m 22.7523s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 36.4093s N, 30 18m 22.5799s E
# [ИНФО][CONTROL] новое направление 340 (было 341)
# [ИНФО][SAFETY] текущие координаты: 59 56m 36.6643s N, 30 18m 22.4072s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 326 (было 340)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 36.8682s N, 30 18m 22.2687s E
# [ИНФО][CONTROL] новое направление 324 (было 326)
# [ИНФО][SAFETY] текущие координаты: 59 56m 37.123s N, 30 18m 22.0953s E
# [ИНФО][CONTROL] новое направление 323 (было 324)
# [ИНФО][SAFETY] текущие координаты: 59 56m 37.3777s N, 30 18m 21.9213s E
# [ИНФО][CONTROL] новое направление 321 (было 323)
# [ИНФО][SAFETY] текущие координаты: 59 56m 37.6321s N, 30 18m 21.7451s E
# [ИНФО][CONTROL] новое направление 320 (было 321)
# [ИНФО][SAFETY] текущие координаты: 59 56m 37.8555s N, 30 18m 21.4455s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 38.0754s N, 30 18m 21.1357s E
# [ИНФО][CONTROL] новое направление 319 (было 320)
# [ИНФО][SAFETY] текущие координаты: 59 56m 38.291s N, 30 18m 20.8143s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 38.5014s N, 30 18m 20.4793s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 38.7102s N, 30 18m 20.1404s E
# [ИНФО][CONTROL] новое направление 318 (было 319)
# [ИНФО][SAFETY] текущие координаты: 59 56m 38.9174s N, 30 18m 19.7976s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 39.1232s N, 30 18m 19.4515s E
# [ИНФО][CONTROL] новое направление 317 (было 318)
# [ИНФО][SAFETY] текущие координаты: 59 56m 39.3282s N, 30 18m 19.1034s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 309 (было 317)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 39.5323s N, 30 18m 18.7533s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 39.7354s N, 30 18m 18.401s E
# [ИНФО][CONTROL] новое направление 308 (было 309)
# [ИНФО][SAFETY] текущие координаты: 59 56m 39.9375s N, 30 18m 18.0461s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.1374s N, 30 18m 17.6866s E
# [ИНФО][CONTROL] новое направление 307 (было 308)
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.3099s N, 30 18m 17.2745s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.4804s N, 30 18m 16.859s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.6486s N, 30 18m 16.44s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.8145s N, 30 18m 16.0171s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 40.9798s N, 30 18m 15.5934s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.1446s N, 30 18m 15.169s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.3092s N, 30 18m 14.7441s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.4736s N, 30 18m 14.319s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.6378s N, 30 18m 13.8937s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.802s N, 30 18m 13.4683s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 41.9661s N, 30 18m 13.0428s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 42.1302s N, 30 18m 12.6171s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 42.2941s N, 30 18m 12.1914s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 3 (было 307)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 42.4579s N, 30 18m 11.7653s E
# [ИНФО][CONTROL] новое направление 5 (было 3)
# [ИНФО][SAFETY] текущие координаты: 59 56m 42.6214s N, 30 18m 11.3388s E
# [ИНФО][CONTROL] новое направление 6 (было 5)
# [ИНФО][SAFETY] текущие координаты: 59 56m 42.7844s N, 30 18m 10.9116s E
# [ИНФО][CONTROL] новое направление 7 (было 6)
# [ИНФО][SAFETY] текущие координаты: 59 56m 43.0531s N, 30 18m 10.9477s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 43.3212s N, 30 18m 10.9981s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 43.5885s N, 30 18m 11.0632s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 43.8557s N, 30 18m 11.1293s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 44.1229s N, 30 18m 11.196s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 44.3901s N, 30 18m 11.2627s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 44.6573s N, 30 18m 11.3295s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 44.9244s N, 30 18m 11.3962s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 45.1916s N, 30 18m 11.463s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 45.4588s N, 30 18m 11.5298s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 45.726s N, 30 18m 11.5965s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 45.9932s N, 30 18m 11.6633s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 46.2603s N, 30 18m 11.7301s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 46.5275s N, 30 18m 11.7969s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 46.7947s N, 30 18m 11.8637s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 47.0619s N, 30 18m 11.9305s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 47.3291s N, 30 18m 11.9973s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 47.5962s N, 30 18m 12.0641s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 47.8634s N, 30 18m 12.131s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 48.1306s N, 30 18m 12.1978s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 48.3978s N, 30 18m 12.2647s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 48.6649s N, 30 18m 12.3315s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 48.8787s N, 30 18m 12.385s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 49.1458s N, 30 18m 12.4519s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 49.413s N, 30 18m 12.5188s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 49.6802s N, 30 18m 12.5857s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 49.9474s N, 30 18m 12.6527s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 50.2145s N, 30 18m 12.7196s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 50.4817s N, 30 18m 12.7866s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 50.7489s N, 30 18m 12.8537s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 40 (было 7)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 51.016s N, 30 18m 12.9208s E
# [ИНФО][CONTROL] новое направление 42 (было 40)
# [ИНФО][SAFETY] текущие координаты: 59 56m 51.2832s N, 30 18m 12.988s E
# [ИНФО][CONTROL] новое направление 45 (было 42)
# [ИНФО][SAFETY] текущие координаты: 59 56m 51.5503s N, 30 18m 13.0556s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 51.7565s N, 30 18m 13.4008s E
# [ИНФО][CONTROL] новое направление 46 (было 45)
# [ИНФО][SAFETY] текущие координаты: 59 56m 51.955s N, 30 18m 13.7636s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 52.1441s N, 30 18m 14.1457s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 52.3315s N, 30 18m 14.5311s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 52.5177s N, 30 18m 14.9189s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 52.7035s N, 30 18m 15.3074s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 52.8892s N, 30 18m 15.6963s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 53.0747s N, 30 18m 16.0854s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 53.2601s N, 30 18m 16.4746s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 53.4454s N, 30 18m 16.8641s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 357 (было 46)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 53.6306s N, 30 18m 17.2537s E
# [ИНФО][CONTROL] новое направление 354 (было 357)
# [ИНФО][SAFETY] текущие координаты: 59 56m 53.8157s N, 30 18m 17.6436s E
# [ИНФО][CONTROL] новое направление 350 (было 354)
# [ИНФО][SAFETY] текущие координаты: 59 56m 54.0006s N, 30 18m 18.0339s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 54.2695s N, 30 18m 18.0075s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 54.5374s N, 30 18m 17.9533s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 54.8033s N, 30 18m 17.8689s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 55.0689s N, 30 18m 17.7801s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 55.3342s N, 30 18m 17.6885s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 55.5995s N, 30 18m 17.5962s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 55.8647s N, 30 18m 17.5035s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 56.1299s N, 30 18m 17.4106s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 56.3951s N, 30 18m 17.3177s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 56.6603s N, 30 18m 17.2247s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 56.9255s N, 30 18m 17.1317s E
# [ИНФО][CONTROL] новое направление 349 (было 350)
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.1907s N, 30 18m 17.0387s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.4559s N, 30 18m 16.9455s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 271 (было 349)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.7211s N, 30 18m 16.8523s E
# [ИНФО][CONTROL] новое направление 265 (было 271)
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.9863s N, 30 18m 16.759s E
# [ИНФО][CONTROL] новое направление 259 (было 265)
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.2514s N, 30 18m 16.6652s E
# [ИНФО][CONTROL] новое направление 257 (было 259)
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.2596s N, 30 18m 16.1286s E
# [ИНФО][CONTROL] новое направление 256 (было 257)
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.2391s N, 30 18m 15.5934s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.1893s N, 30 18m 15.0658s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.1326s N, 30 18m 14.5411s E
# [ИНФО][CONTROL] новое направление 255 (было 256)
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.0709s N, 30 18m 14.0185s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.0073s N, 30 18m 13.4969s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.9424s N, 30 18m 12.9759s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.8767s N, 30 18m 12.4553s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 353 (было 255)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.8104s N, 30 18m 11.935s E
# [ИНФО][CONTROL] новое направление 355 (было 353)
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.7436s N, 30 18m 11.415s E
# [ИНФО][CONTROL] новое направление 358 (было 355)
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.6758s N, 30 18m 10.8955s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 57.9432s N, 30 18m 10.833s E
# [ИНФО][CONTROL] новое направление 359 (было 358)
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.2118s N, 30 18m 10.7954s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.4272s N, 30 18m 10.7849s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.6964s N, 30 18m 10.7738s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 58.9656s N, 30 18m 10.7642s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 59.2348s N, 30 18m 10.755s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 59.5041s N, 30 18m 10.746s E
# [ИНФО][SAFETY] текущие координаты: 59 56m 59.7733s N, 30 18m 10.737s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 0.0425437s N, 30 18m 10.7281s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 0.311778s N, 30 18m 10.7191s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 0.581013s N, 30 18m 10.7101s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 0.850247s N, 30 18m 10.7011s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 1.11948s N, 30 18m 10.6921s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 1.38872s N, 30 18m 10.6832s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 1.65795s N, 30 18m 10.6742s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 1.92719s N, 30 18m 10.6652s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 2.19642s N, 30 18m 10.6562s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 2.46565s N, 30 18m 10.6472s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 2.73489s N, 30 18m 10.6382s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.00412s N, 30 18m 10.6292s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.27336s N, 30 18m 10.6202s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 270 (было 359)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.54259s N, 30 18m 10.6112s E
# [ИНФО][CONTROL] новое направление 266 (было 270)
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.81183s N, 30 18m 10.6022s E
# [ИНФО][CONTROL] новое направление 263 (было 266)
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.08106s N, 30 18m 10.5931s E
# [ИНФО][CONTROL] новое направление 262 (было 263)
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.0829s N, 30 18m 10.0563s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.06743s N, 30 18m 9.5203s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.0348s N, 30 18m 8.98741s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.99984s N, 30 18m 8.45512s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.96488s N, 30 18m 7.92282s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.9285s N, 30 18m 7.3909s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.89183s N, 30 18m 6.85906s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.85501s N, 30 18m 6.32725s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.81803s N, 30 18m 5.7955s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.78099s N, 30 18m 5.26376s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.74392s N, 30 18m 4.73203s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.70682s N, 30 18m 4.20031s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.6697s N, 30 18m 3.66859s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.63259s N, 30 18m 3.13688s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.59548s N, 30 18m 2.60516s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 280 (было 262)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.55839s N, 30 18m 2.07344s E
# [ИНФО][CONTROL] новое направление 281 (было 280)
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.52132s N, 30 18m 1.54171s E
# [ИНФО][CONTROL] новое направление 282 (было 281)
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.48432s N, 30 18m 1.00996s E
# [ИНФО][CONTROL] новое направление 283 (было 282)
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.44757s N, 30 18m 0.478142s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.49873s N, 30 17m 59.9511s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.55353s N, 30 17m 59.4255s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.61224s N, 30 17m 58.9015s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.67518s N, 30 17m 58.3796s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.73868s N, 30 17m 57.8579s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.80262s N, 30 17m 57.3364s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.86683s N, 30 17m 56.815s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.93111s N, 30 17m 56.2937s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 3.99543s N, 30 17m 55.7724s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.05976s N, 30 17m 55.2511s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.1241s N, 30 17m 54.7298s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.18843s N, 30 17m 54.2085s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.25275s N, 30 17m 53.6872s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.31707s N, 30 17m 53.1659s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.36851s N, 30 17m 52.7489s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.4328s N, 30 17m 52.2275s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.49707s N, 30 17m 51.7062s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.56132s N, 30 17m 51.1849s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.62555s N, 30 17m 50.6635s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.68976s N, 30 17m 50.1422s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.75393s N, 30 17m 49.6208s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 16 (было 283)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.81805s N, 30 17m 49.0994s E
# [ИНФО][CONTROL] новое направление 26 (было 16)
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.8821s N, 30 17m 48.578s E
# [ИНФО][CONTROL] новое направление 34 (было 26)
# [ИНФО][SAFETY] текущие координаты: 59 57m 4.946s N, 30 17m 48.0564s E
# [ИНФО][CONTROL] новое направление 42 (было 34)
# [ИНФО][SAFETY] текущие координаты: 59 57m 5.00949s N, 30 17m 47.5347s E
# [ИНФО][CONTROL] новое направление 46 (было 42)
# [ИНФО][SAFETY] текущие координаты: 59 57m 5.26723s N, 30 17m 47.6902s E
# [ИНФО][CONTROL] новое направление 50 (было 46)
# [ИНФО][SAFETY] текущие координаты: 59 57m 5.50895s N, 30 17m 47.9267s E
# [ИНФО][CONTROL] новое направление 54 (было 50)
# [ИНФО][CONTROL] новое направление 58 (было 54)
# [ИНФО][SAFETY] текущие координаты: 59 57m 5.72994s N, 30 17m 48.2335s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 5.92804s N, 30 17m 48.5971s E
# [ИНФО][CONTROL] новое направление 63 (было 58)
# [ИНФО][CONTROL] новое направление 74 (было 63)
# [ИНФО][SAFETY] текущие координаты: 59 57m 6.11235s N, 30 17m 48.9885s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 333 (было 74)
# [ИНФО][SAFETY] текущие координаты: 59 57m 6.28251s N, 30 17m 49.4045s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 324 (было 333)
# [ИНФО][SAFETY] текущие координаты: 59 57m 6.4383s N, 30 17m 49.8424s E
# [ИНФО][CONTROL] новое направление 315 (было 324)
# [ИНФО][SAFETY] текущие координаты: 59 57m 6.57916s N, 30 17m 50.3s E
# [ИНФО][CONTROL] новое направление 308 (было 315)
# [ИНФО][SAFETY] текущие координаты: 59 57m 6.69799s N, 30 17m 50.7817s E
# [ИНФО][CONTROL] новое направление 304 (было 308)[ИНФО][SAFETY] текущие координаты: 59 57m 6.77015s N, 30 17m 51.2989s E
#
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.01183s N, 30 17m 51.0622s E
# [ИНФО][CONTROL] новое направление 300 (было 304)
# [ИНФО][CONTROL] новое направление 296 (было 300)
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.23089s N, 30 17m 50.75s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.42289s N, 30 17m 50.3736s E
# [ИНФО][CONTROL] новое направление 293 (было 296)
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.57353s N, 30 17m 49.9286s E
# [ИНФО][CONTROL] новое направление 289 (было 293)
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.72417s N, 30 17m 49.4836s E
# [ИНФО][CONTROL] новое направление 282 (было 289)
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.8436s N, 30 17m 49.0025s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 338 (было 282)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 7.95251s N, 30 17m 48.5115s E
# [ИНФО][CONTROL] новое направление 344 (было 338)
# [ИНФО][SAFETY] текущие координаты: 59 57m 8.0407s N, 30 17m 48.0042s E
# [ИНФО][CONTROL] новое направление 352 (было 344)
# [ИНФО][SAFETY] текущие координаты: 59 57m 8.10065s N, 30 17m 47.4809s E
# [ИНФО][CONTROL] новое направление 355 (было 352)
# [ИНФО][SAFETY] текущие координаты: 59 57m 8.35065s N, 30 17m 47.2814s E
# [ИНФО][CONTROL] новое направление 358 (было 355)
# [ИНФО][SAFETY] текущие координаты: 59 57m 8.6104s N, 30 17m 47.1399s E
# [ИНФО][CONTROL] новое направление 359 (было 358)
# [ИНФО][SAFETY] текущие координаты: 59 57m 8.87757s N, 30 17m 47.0729s E
# [ИНФО][CONTROL] новое направление 1 (было 359)
# [ИНФО][SAFETY] текущие координаты: 59 57m 9.14604s N, 30 17m 47.0316s E
# [ИНФО][CONTROL] новое направление 4 (было 1)
# [ИНФО][SAFETY] текущие координаты: 59 57m 9.41516s N, 30 17m 47.0137s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 9.68443s N, 30 17m 47.0108s E
# [ИНФО][CONTROL] новое направление 5 (было 4)
# [ИНФО][SAFETY] текущие координаты: 59 57m 9.95361s N, 30 17m 47.0245s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 10.2222s N, 30 17m 47.0625s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 10.4906s N, 30 17m 47.1069s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 10.7588s N, 30 17m 47.1544s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 11.0269s N, 30 17m 47.2029s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 11.2951s N, 30 17m 47.252s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 11.5632s N, 30 17m 47.3013s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 11.8314s N, 30 17m 47.3508s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 12.0995s N, 30 17m 47.4004s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 12.3676s N, 30 17m 47.45s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 1 (было 5)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 12.6357s N, 30 17m 47.4997s E
# [ИНФО][CONTROL] новое направление 0 (было 1)
# [ИНФО][SAFETY] текущие координаты: 59 57m 12.9038s N, 30 17m 47.5496s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 13.1183s N, 30 17m 47.5897s E
# [ИНФО][CONTROL] новое направление 359 (было 0)
# [ИНФО][SAFETY] текущие координаты: 59 57m 13.3875s N, 30 17m 47.6026s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 13.6567s N, 30 17m 47.6097s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 13.926s N, 30 17m 47.6105s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 14.1953s N, 30 17m 47.6087s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 352 (было 359)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 14.4645s N, 30 17m 47.6043s E
# [ИНФО][CONTROL] новое направление 351 (было 352)
# [ИНФО][SAFETY] текущие координаты: 59 57m 14.7338s N, 30 17m 47.5979s E
# [ИНФО][CONTROL] новое направление 350 (было 351)
# [ИНФО][SAFETY] текущие координаты: 59 57m 15.003s N, 30 17m 47.5886s E
# [ИНФО][CONTROL] новое направление 349 (было 350)
# [ИНФО][SAFETY] текущие координаты: 59 57m 15.2703s N, 30 17m 47.5229s E
# [ИНФО][CONTROL] новое направление 348 (было 349)
# [ИНФО][SAFETY] текущие координаты: 59 57m 15.5368s N, 30 17m 47.4461s E
# [ИНФО][CONTROL] новое направление 346 (было 348)
# [ИНФО][SAFETY] текущие координаты: 59 57m 15.802s N, 30 17m 47.3539s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 40 (было 346)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 16.0666s N, 30 17m 47.2537s E
# [ИНФО][CONTROL] новое направление 42 (было 40)
# [ИНФО][SAFETY] текущие координаты: 59 57m 16.3301s N, 30 17m 47.1436s E
# [ИНФО][CONTROL] новое направление 44 (было 42)
# [ИНФО][SAFETY] текущие координаты: 59 57m 16.5922s N, 30 17m 47.0199s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 16.7969s N, 30 17m 47.3686s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 16.9963s N, 30 17m 47.7295s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.1897s N, 30 17m 48.103s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.3827s N, 30 17m 48.4775s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.5754s N, 30 17m 48.8525s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.768s N, 30 17m 49.2277s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.9606s N, 30 17m 49.6029s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.1532s N, 30 17m 49.9781s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.3458s N, 30 17m 50.3534s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.5384s N, 30 17m 50.7286s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.731s N, 30 17m 51.1039s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.9235s N, 30 17m 51.4792s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.1161s N, 30 17m 51.8546s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.3086s N, 30 17m 52.2299s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.5011s N, 30 17m 52.6053s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.6936s N, 30 17m 52.9807s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.8861s N, 30 17m 53.3562s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.0786s N, 30 17m 53.7317s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.271s N, 30 17m 54.1072s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.4634s N, 30 17m 54.4828s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.6558s N, 30 17m 54.8584s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.8482s N, 30 17m 55.2341s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.0405s N, 30 17m 55.6099s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.2328s N, 30 17m 55.9858s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.425s N, 30 17m 56.3618s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 36 (было 44)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.6171s N, 30 17m 56.7381s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.809s N, 30 17m 57.1148s E
# [ИНФО][CONTROL] новое направление 35 (было 36)
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.0001s N, 30 17m 57.493s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.2162s N, 30 17m 57.8133s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.4337s N, 30 17m 58.13s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.6527s N, 30 17m 58.4424s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.8719s N, 30 17m 58.7542s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.0912s N, 30 17m 59.0657s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.3106s N, 30 17m 59.3771s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.5299s N, 30 17m 59.6886s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.7492s N, 30 18m 6.26972e-05s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.9686s N, 30 18m 0.311582s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.1879s N, 30 18m 0.623155s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.4071s N, 30 18m 0.934791s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.5825s N, 30 18m 1.18416s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.8018s N, 30 18m 1.49595s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.0209s N, 30 18m 1.80786s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 123 (было 35)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.2401s N, 30 18m 2.1199s E
# [ИНФО][CONTROL] новое направление 127 (было 123)
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.4591s N, 30 18m 2.43224s E
# [ИНФО][CONTROL] новое направление 130 (было 127)
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.6779s N, 30 18m 2.74515s E
# [ИНФО][CONTROL] новое направление 131 (было 130)
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.5305s N, 30 18m 3.19452s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.3684s N, 30 18m 3.62329s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.1924s N, 30 18m 4.02964s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 25.0145s N, 30 18m 4.43268s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.8354s N, 30 18m 4.83367s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.6561s N, 30 18m 5.23424s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.4767s N, 30 18m 5.63462s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.2973s N, 30 18m 6.03495s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 24.1178s N, 30 18m 6.4353s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.9384s N, 30 18m 6.83568s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.759s N, 30 18m 7.2361s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.5797s N, 30 18m 7.63659s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.4004s N, 30 18m 8.03715s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.2211s N, 30 18m 8.43783s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 117 (было 131)
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 23.0419s N, 30 18m 8.83866s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.8629s N, 30 18m 9.23976s E
# [ИНФО][CONTROL] новое направление 116 (было 117)
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.6843s N, 30 18m 9.64155s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.5589s N, 30 18m 10.1167s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.4355s N, 30 18m 10.5939s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.3142s N, 30 18m 11.0732s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.193s N, 30 18m 11.5527s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 22.072s N, 30 18m 12.0324s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.9509s N, 30 18m 12.512s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.8299s N, 30 18m 12.9916s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.7089s N, 30 18m 13.4713s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.5879s N, 30 18m 13.9509s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.4669s N, 30 18m 14.4306s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.3459s N, 30 18m 14.9102s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.2249s N, 30 18m 15.3899s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 21.1039s N, 30 18m 15.8696s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.9829s N, 30 18m 16.3493s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.862s N, 30 18m 16.829s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.741s N, 30 18m 17.3087s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.6201s N, 30 18m 17.7884s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.4992s N, 30 18m 18.2681s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.3783s N, 30 18m 18.7479s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.2574s N, 30 18m 19.2276s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.1365s N, 30 18m 19.7074s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 20.0156s N, 30 18m 20.1872s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.8948s N, 30 18m 20.667s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.774s N, 30 18m 21.1468s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.6532s N, 30 18m 21.6267s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.5324s N, 30 18m 22.1066s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 119 (было 116)
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.4359s N, 30 18m 22.4906s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.3153s N, 30 18m 22.9706s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.1947s N, 30 18m 23.4507s E
# [ИНФО][CONTROL] новое направление 120 (было 119)
# [ИНФО][SAFETY] текущие координаты: 59 57m 19.0744s N, 30 18m 23.931s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.9544s N, 30 18m 24.4117s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.8223s N, 30 18m 24.8796s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.6891s N, 30 18m 25.3462s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.5546s N, 30 18m 25.8113s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.4183s N, 30 18m 26.2744s E
# [ИНФО][CONTROL] новое направление 121 (было 120)
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.2815s N, 30 18m 26.7368s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.1442s N, 30 18m 27.1986s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новое направление 120 (было 121)
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.0063s N, 30 18m 27.6599s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 119 (было 120)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.8681s N, 30 18m 28.1207s E
# [ИНФО][CONTROL] сегмент пройден
# [ИНФО][CONTROL] новая скорость 20 (была 60)
# [ИНФО][CONTROL] новое направление 67 (было 119)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.7296s N, 30 18m 28.581s E
# [ИНФО][SAFETY] сегмент пройден
# [ИНФО][CONTROL] новое направление 62 (было 67)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.5905s N, 30 18m 29.0408s E
# [ИНФО][CONTROL] новое направление 56 (было 62)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.4507s N, 30 18m 29.4996s E
# [ИНФО][CONTROL] новое направление 49 (было 56)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.3151s N, 30 18m 29.9635s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.1832s N, 30 18m 30.4316s E
# [ИНФО][CONTROL] новое направление 48 (было 49)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.2179s N, 30 18m 30.5967s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.2599s N, 30 18m 30.7548s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.3098s N, 30 18m 30.9037s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.3677s N, 30 18m 31.0404s E
# [ИНФО][CONTROL] новое направление 47 (было 48)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.4264s N, 30 18m 31.1757s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.4859s N, 30 18m 31.3098s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.5458s N, 30 18m 31.4431s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.6058s N, 30 18m 31.5762s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.6658s N, 30 18m 31.7093s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.7259s N, 30 18m 31.8422s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.7859s N, 30 18m 31.9752s E
# [ИНФО][CONTROL] новое направление 48 (было 47)
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.846s N, 30 18m 32.1082s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.9061s N, 30 18m 32.2411s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 17.9662s N, 30 18m 32.3741s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.0262s N, 30 18m 32.5071s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.0863s N, 30 18m 32.6401s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.1464s N, 30 18m 32.7731s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.2064s N, 30 18m 32.9062s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.2664s N, 30 18m 33.0392s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.3264s N, 30 18m 33.1723s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.3865s N, 30 18m 33.3054s E
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.4465s N, 30 18m 33.4385s E
# [ИНФО][CONTROL] маршрут пройден, текущее время 20:23:33.761730
# [ИНФО][CONTROL] новая скорость 0.0 (была 20)
# [ИНФО][CONTROL] новое направление 0 (было 48)
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] текущие координаты: 59 57m 18.5064s N, 30 18m 33.5716s E
# [ОШИБКА][SAFETY] ошибка обработки команд: 'NoneType' object has no attribute 'longitude'
# [ИНФО][CARGO] выгрузка
# [ИНФО][CARGO] груз оставлен
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден
# [ИНФО][SAFETY] маршрут пройден

# %% [markdown]
# На этом модуль 3 завершён!
#
# Если у вас всё получилось, то вы создали защищённую автономную машинку - ещё уже не так-то просто использовать для нанесения критического ущерба людям и имуществу, потому что самые критические режимы проверяются вашим Ограничителем, а если вы ещё и внедрили Монитор Безопасности, то теперь злоумышленнику гораздо сложнее атаковать внутренние блоки, даже если он смог проникнуть в какую-то бортовую систему или внедрить вредоносный код.
#
# Осталось проверить эффективность получившейся защиты на полной трассе - в этом и заключается модуль 4 задания, для перехода к которому нужно открыть блокнот с именем cyberimmunity--autonomous-car-m4. Успеха!
